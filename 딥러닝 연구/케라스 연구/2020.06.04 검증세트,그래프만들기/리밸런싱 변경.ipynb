# %% [markdown]
# # python 에 필요한 module 불러오기

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from math import exp

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import FinanceDataReader as fdr
from sklearn.metrics import accuracy_score

# %% [markdown]
# # 특성(MA,Stochastic,rsi) 추가

# %%
#특성 추가 ------------------------------------------
    #이동평균선
def get_MA(df):
    MA_26=df["Close"].rolling(26).mean()
    MA_52=df["Close"].rolling(52).mean()
    df=df.assign(MA_26=MA_26,MA_52=MA_52).dropna()
    
    return df

    
    #스토캐스틱
def get_stochastic(df, n=15, m=5, t=3):
    # n일중 최고가
    ndays_high = df.High.rolling(window=n, min_periods=1).max()
    # n일중 최저가
    ndays_low = df.Low.rolling(window=n, min_periods=1).min()
 
    # Fast%K 계산
    kdj_k = ((df.Close - ndays_low) / (ndays_high - ndays_low))*100
    # Fast%D (=Slow%K) 계산
    kdj_d = kdj_k.ewm(span=m).mean()
    # Slow%D 계산
    kdj_j = kdj_d.ewm(span=t).mean()
 
    # dataframe에 컬럼 추가
    df = df.assign(kdj_k=kdj_k, kdj_d=kdj_d, kdj_j=kdj_j).dropna()
    
    return df


def rsi(values):
    up = values[values>0].mean()
    down = -1*values[values<0].mean()
    return 100 * up / (up + down)
# Add Momentum_1D column for all 15 stocks.
# Momentum_1D = P(t) - P(t-1)

# %% [markdown]
# # 주식 데이터 불러오기

# %%
KS11 = fdr.DataReader("KS11","2009-01-01","2019-01-01") #코스피
KQ11= fdr.DataReader("KQ11","2009-01-01","2019-01-01") #코스닥
US500 = fdr.DataReader("US500","2009-01-01","2019-01-01") #SP500
HSI = fdr.DataReader("HSI","2009-01-01","2019-01-01") #항생지수
IXIC = fdr.DataReader("IXIC","2009-01-01","2019-01-01") #나스닥

KS11 = KS11.drop(['Volume'], axis = 1 )
KQ11 = KQ11.drop(['Volume'], axis = 1 )
US500 = US500.drop(['Volume'], axis = 1 )
HSI = HSI.drop(['Volume'], axis = 1 )
IXIC = IXIC.drop(['Volume'], axis = 1 )

# %% [markdown]
# # 사용될 변수 생성

# %%
예측dic={}
수익률dic={}
EndSwitch = 1 # 0이 되면 반복 종료
초기돈 = 10000
d,dd= 1, 20
BATCH = 20 # 리밸런싱 주기
count = 0 # 리밸런싱된 횟수 count
pred_dic={}
투자결과=[]

all_df=pd.DataFrame(columns=["영업일","인덱스","상승예측확률","실제수익률"]) # 총 table
set_df=pd.DataFrame(columns=["영업일","인덱스","상승예측확률","실제수익률"]) # 20일 주기 table

# %% [markdown]
# # Main 모델

# %%
for 인덱스,인덱스명 in zip([KS11,KQ11,IXIC,HSI,US500],["코스피","코스닥","나스닥","항생","S&P500"]):
    df = 인덱스
    
    # 특성 추가--------------------------------------------------------
    
    
        #스토캐스틱과 이동평균선
    df=get_stochastic(df)
    df=get_MA(df)
    
        #RSI
    df['Momentum_1D'] = (df['Close']-df['Close'].shift(1))
    df['RSI_14D'] = df['Momentum_1D'].rolling(center=False, window=14).apply(rsi)
    df=df.dropna()
    df=df[0:-(len(df)%BATCH)]
    df = df.drop(labels = ['Momentum_1D'], axis=1)
    
        #이동평균선
    MA_26=df["Close"].rolling(21).mean()
    df_MA=MA_26.dropna()
    df_char=df[20:] # df_char : 특성 모두 추가한 data 
       #------------------------------------------------------------------
    
    
    
    
        # y ( target ) 생성 -----------------------------------------------------------
    y=[]
    for x in range(1,10001): # 10001은 try를 못할때까지의 임의의 값
        try:
            if (df_char["Close"][20*(x-1)]>df_MA[20*x]): #값(df_char)과 이동평균선(df_MA) 비교
                for _ in range(20):
                    y.append(1)
            else:
                for __ in range(20):
                    y.append(0)
        except:
            break
        #-------------------------------------------------------------------

    
 
    
    
    df = df_char[:-20] #y를 shifting 한만큼 x도 처리
    nparr = df # 스케일링 할 데이터
    nparr2 = df # 스케일링 안한 데이터 백업
    
    #normalizing
    scaler = MinMaxScaler(feature_range=(0, 1))
    df["Close"]=scaler.fit_transform(nparr["Close"].values.reshape(-1,1))
    df["Open"]=scaler.fit_transform(nparr["Open"].values.reshape(-1,1))
    df["High"]=scaler.fit_transform(nparr["High"].values.reshape(-1,1))
    df["Low"]=scaler.fit_transform(nparr["Low"].values.reshape(-1,1))
    df["Change"]=scaler.fit_transform(nparr["Change"].values.reshape(-1,1))
    df["kdj_k"]=scaler.fit_transform(nparr["kdj_k"].values.reshape(-1,1))
    df["kdj_d"]=scaler.fit_transform(nparr["kdj_d"].values.reshape(-1,1))
    df["kdj_j"]=scaler.fit_transform(nparr["kdj_j"].values.reshape(-1,1))
    df["MA_26"]=scaler.fit_transform(nparr["MA_26"].values.reshape(-1,1))
    df["MA_52"]=scaler.fit_transform(nparr["MA_52"].values.reshape(-1,1))
    df["RSI_14D"]=scaler.fit_transform(nparr["RSI_14D"].values.reshape(-1,1))
    
    #-----
    #df["y"]=y
    #print(df.corr()) #상관관계 분석 ( 출력하고 싶다면 주석 제거)
    #df = df.drop(['y'],axis = 1)
    #-----
    
    df = df.drop(['Close','Open','High','Low','MA_26','MA_52'], axis = 1 ) # 상관관계 분석 후 관계 적은 특성(열) 제거
    X=df.values
    
    # train test val 세팅
    setlen=int(len(X)/20*0.7)*20 # 데이터를 7:3으로 나누고 20의 배수로 만듬
    X_train=X[:setlen]
    X_test=X[setlen:]
    y_train=y[:setlen]
    y_test=y[setlen:]
    
    setlen2=int(len(X_train)/20*0.3)*20 # 검증 데이터를 3:7으로 나누고 20의 배수로 만듬
    X_val = X_train[ : setlen2]
    y_val = y_train[ : setlen2]
    X_train2 = X_train[setlen2 : ]
    y_train2 = y_train[setlen2 : ]
    
    
    # 딥러닝 모델에 맞는 사이즈로 전처리
    X_train = np.reshape(X_train, (X_train.shape[0],1, X_train.shape[1]))
    X_test = np.reshape(X_test, (X_test.shape[0],1, X_test.shape[1]))
    
    X_val = np.reshape(X_val, (X_val.shape[0],1, X_val.shape[1]))
    X_train2 = np.reshape(X_train2, (X_train2.shape[0],1, X_train2.shape[1]))
    
    #LSTM모델 생성
    model = Sequential()
    model.add(LSTM(36, input_shape=(1, 5),return_sequences=True))
    model.add(LSTM(36, input_shape=(1, 5)))
    for i in range(2):
        model.add(Dense(18,activation='relu'))
        model.add(Dropout(0.1))
    model.add(Dense(1,activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    
    history = model.fit(X_train2, y_train2, epochs=100, batch_size=16,validation_data=(X_val,y_val),verbose=0)
    
    history_dict= history.history
    loss_values = history_dict['loss']
    val_loss_values = history_dict['val_loss']
    acc = history_dict['accuracy']
    epochs = range(1,len(acc)+1)

    plt.plot(epochs,loss_values,'bo',label='Training loss')
    plt.plot(epochs,val_loss_values,'b',label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    pred=np.where(model.predict(X_test)>0.5,1,0)
    예측dic[인덱스명]=pred # 예측 데이터 table에 추가
    수익률dic[인덱스명]=nparr2["Close"][setlen:] #투자 결과를 보기 위해 실제 수익률을 구함

    print(인덱스명, "정확도 : ", accuracy_score(y_test,np.where(model.predict(X_test)>0.5,1,0)))
       
    #모델 생성 완료 ------------------------------


End=1
while End==1: # 종료조건 ( END =0 )까지 반복
    
    # 날짜 출력 ------   
    day= str(d) +"~" + str(dd) + "일 차"
    print(day,"---------------------------------")
    # --------------- 
    set_df=pd.DataFrame(columns=["영업일","인덱스","상승예측확률","실제수익률"])

    
    
    for key,val in zip(예측dic.keys(),예측dic.values()): 
    
    
        #----------------------- 지수함수로 중요 비중 조정
        e_sum = 0
        for xx in range(1,21):
            e_sum=e_sum+exp(xx)

        pred_list=[]
        rank=1
        pred=val[BATCH-20:BATCH] # BATCH는 0부터 매 리밸런싱마다 20씩 증가
        
        for yy in pred:
            pred_list.append(yy*rank)
            rank = rank + 1       # ex ) [1,1,1,0,1,0,..] -> [1,2,3,0,5,0..] 로 가중치를 줌


        pred_sum=0
        for zz in pred_list:
            pred_sum=pred_sum+(exp(zz)/e_sum) # 가중치를 e에 대입
        pred_sum=round(pred_sum,4) # 소수 4번째 반올림
        #--------------------------------------------------
        
        
        # 예측 결과를 표(dataframe)로 보기 쉽게 정리-----------------
        if count==0:
            pred_dic[key]=pred_sum #pred_dic == {}
        else:
            pred_dic[key]=np.append(pred_dic[key],pred_sum)
        예측 = pred_sum
        실제수익률 = ((수익률dic[key][BATCH+19])/(수익률dic[key][BATCH]))-1
        turn_df=pd.DataFrame(data={"영업일":[day],"인덱스":[key],"상승예측확률":[예측],"실제수익률":[실제수익률] }, columns=["영업일","인덱스","상승예측확률","실제수익률"])
        set_df=pd.concat([set_df,turn_df])    
        #------------------------------------------------------------
        
    #--------데이터 20개 중 60% 이상 상승 예측 시 list에 추가
    earn_list=[]
    
    for x,y in zip(set_df["상승예측확률"],set_df["실제수익률"]):
        
        if x>=0.6:
            earn_list.append(y)
    
    #-------하나도 상승 예측이 아니었다면 규제 줄이기
    if len(earn_list)==0:
        for x,y in zip(set_df["상승예측확률"],set_df["실제수익률"]):
        
            if x>=0.4:
                earn_list.append(y)
    #---------------------------------------------------------------------
    
    
    earn_list2=[]
    if len(earn_list)!=0:
        초기돈=초기돈/(len(earn_list))
        for y in earn_list:
            earn_list2.append(초기돈+(초기돈*y))
        초기돈=sum(earn_list2)    
    else:
        earn_list2.append(초기돈)
    

    all_df=pd.concat([all_df,set_df])
    BATCH=BATCH+20

    print("분산 투자 : ",earn_list2)
    print("투자 결과 : ",초기돈)
    print(set_df.head(5))
    count=count+1
    d=d+20
    dd=dd+20

        #종료조건---------------

    if(len(수익률dic[key])==BATCH+20):
        End=0
        print("------------종료------------  ◆리밸런싱 수◆ : " , count)
        break
        #----------------------------------
# Out:
# 코스피 정확도 :  0.6833333333333333
# 코스닥 정확도 :  0.7194444444444444
# 나스닥 정확도 :  0.6875
# 항생 정확도 :  0.6986111111111111
# S&P500 정확도 :  0.7541666666666667
# 1~20일 차 ---------------------------------
# 분산 투자 :  [3325.1956631004527, 3770.392189555198, 2926.983641645009]
# 투자 결과 :  10022.57149430066
#        영업일     인덱스  상승예측확률     실제수익률
# 0  1~20일 차     코스피  0.9949 -0.002441
# 0  1~20일 차     코스닥  0.0025  0.003883
# 0  1~20일 차     나스닥  1.0000  0.131118
# 0  1~20일 차      항생  1.0000 -0.121905
# 0  1~20일 차  S&P500  0.0923  0.119830
# 21~40일 차 ---------------------------------
# 분산 투자 :  [15135.233511473369]
# 투자 결과 :  15135.233511473369
#         영업일     인덱스  상승예측확률     실제수익률
# 0  21~40일 차     코스피  0.0025  0.063096
# 0  21~40일 차     코스닥  0.0001 -0.006145
# 0  21~40일 차     나스닥  0.0003  0.060298
# 0  21~40일 차      항생  1.0000  0.510115
# 0  21~40일 차  S&P500  0.0000  0.057339
# 41~60일 차 ---------------------------------
# 분산 투자 :  [15135.233511473369]
# 투자 결과 :  15135.233511473369
#         영업일     인덱스  상승예측확률     실제수익률
# 0  41~60일 차     코스피  0.0000  0.003269
# 0  41~60일 차     코스닥  0.0067  0.023125
# 0  41~60일 차     나스닥  0.0000 -0.008284
# 0  41~60일 차      항생  0.0000  0.264202
# 0  41~60일 차  S&P500  0.0000  0.031097
# 61~80일 차 ---------------------------------
# 분산 투자 :  [7492.6006802905595, 8018.983241743716]
# 투자 결과 :  15511.583922034275
#         영업일     인덱스  상승예측확률     실제수익률
# 0  61~80일 차     코스피  0.9817 -0.009913
# 0  61~80일 차     코스닥  0.0000 -0.018464
# 0  61~80일 차     나스닥  0.9991  0.059644
# 0  61~80일 차      항생  0.0497 -0.260128
# 0  61~80일 차  S&P500  0.0000  0.028364
# 81~100일 차 ---------------------------------
# 분산 투자 :  [5412.693836579684, 5251.284121672123, 5529.702126068172]
# 투자 결과 :  16193.680084319978
#          영업일     인덱스  상승예측확률     실제수익률
# 0  81~100일 차     코스피  0.9817  0.046836
# 0  81~100일 차     코스닥  0.9817  0.015619
# 0  81~100일 차     나스닥  0.1353 -0.079190
# 0  81~100일 차      항생  1.0000  0.069466
# 0  81~100일 차  S&P500  0.1353 -0.051828
# 101~120일 차 ---------------------------------
# 분산 투자 :  [6022.704651574797, 6492.0635292097395, 5831.893699595447]
# 투자 결과 :  18346.661880379983
#           영업일     인덱스  상승예측확률     실제수익률
# 0  101~120일 차     코스피  0.0067 -0.055856
# 0  101~120일 차     코스닥  0.0183 -0.038242
# 0  101~120일 차     나스닥  1.0000  0.115751
# 0  101~120일 차      항생  0.8647  0.202703
# 0  101~120일 차  S&P500  1.0000  0.080402
# 121~140일 차 ---------------------------------
# 분산 투자 :  [18346.661880379983]
# 투자 결과 :  18346.661880379983
#           영업일     인덱스  상승예측확률     실제수익률
# 0  121~140일 차     코스피  0.0498  0.111225
# 0  121~140일 차     코스닥  0.1353  0.055769
# 0  121~140일 차     나스닥  0.0000  0.017964
# 0  121~140일 차      항생  0.0498  0.191966
# 0  121~140일 차  S&P500  0.0000  0.004168
# 141~160일 차 ---------------------------------
# 분산 투자 :  [5382.161870785019, 6335.010029924472, 6137.825179722586]
# 투자 결과 :  17854.997080432076
#           영업일     인덱스  상승예측확률     실제수익률
# 0  141~160일 차     코스피  0.0000  0.062846
# 0  141~160일 차     코스닥  0.6321 -0.119922
# 0  141~160일 차     나스닥  0.6321  0.035885
# 0  141~160일 차      항생  0.0058  0.176844
# 0  141~160일 차  S&P500  0.6321  0.003642
# 161~180일 차 ---------------------------------
# 분산 투자 :  [6147.699313123271, 6283.425464501411, 5843.563859301827]
# 투자 결과 :  18274.68863692651
#           영업일     인덱스  상승예측확률     실제수익률
# 0  161~180일 차     코스피  0.9502  0.032938
# 0  161~180일 차     코스닥  1.0000  0.055742
# 0  161~180일 차     나스닥  0.1353 -0.017553
# 0  161~180일 차      항생  0.0002 -0.031579
# 0  161~180일 차  S&P500  1.0000 -0.018163
# 181~200일 차 ---------------------------------
# 분산 투자 :  [6221.371871392635, 5557.41144962478, 6313.402478602861]
# 투자 결과 :  18092.185799620274
#           영업일     인덱스  상승예측확률     실제수익률
# 0  181~200일 차     코스피  0.0003 -0.065867
# 0  181~200일 차     코스닥  0.0001 -0.214071
# 0  181~200일 차     나스닥  1.0000  0.021310
# 0  181~200일 차      항생  1.0000 -0.087687
# 0  181~200일 차  S&P500  1.0000  0.036418
# 201~220일 차 ---------------------------------
# 분산 투자 :  [6025.364918227354, 5724.143801579521, 6285.030067990303]
# 투자 결과 :  18034.53878779718
#           영업일     인덱스  상승예측확률     실제수익률
# 0  201~220일 차     코스피  1.0000 -0.000889
# 0  201~220일 차     코스닥  1.0000 -0.050837
# 0  201~220일 차     나스닥  0.3679  0.031622
# 0  201~220일 차      항생  1.0000  0.042168
# 0  201~220일 차  S&P500  0.0498  0.058468
# 221~240일 차 ---------------------------------
# 분산 투자 :  [6577.884801064947, 6729.117951428825, 5738.121767051666]
# 투자 결과 :  19045.12451954544
#           영업일     인덱스  상승예측확률     실제수익률
# 0  221~240일 차     코스피  0.7559  0.094215
# 0  221~240일 차     코스닥  0.9952  0.119372
# 0  221~240일 차     나스닥  0.0009  0.025891
# 0  221~240일 차      항생  0.9570 -0.045478
# 0  221~240일 차  S&P500  0.0000  0.006766
# 241~260일 차 ---------------------------------
# 분산 투자 :  [21378.449795710683]
# 투자 결과 :  21378.449795710683
#           영업일     인덱스  상승예측확률     실제수익률
# 0  241~260일 차     코스피  0.0000  0.063936
# 0  241~260일 차     코스닥  0.0000 -0.080976
# 0  241~260일 차     나스닥  0.0009  0.072076
# 0  241~260일 차      항생  1.0000  0.122516
# 0  241~260일 차  S&P500  0.0061  0.061796
# 261~280일 차 ---------------------------------
# 분산 투자 :  [10844.895374550471, 10582.982481134402]
# 투자 결과 :  21427.877855684874
#           영업일     인덱스  상승예측확률     실제수익률
# 0  261~280일 차     코스피  0.8647  0.014563
# 0  261~280일 차     코스닥  0.9997 -0.009939
# 0  261~280일 차     나스닥  0.0000  0.020686
# 0  261~280일 차      항생  0.0000  0.027083
# 0  261~280일 차  S&P500  0.0007  0.023268
# 281~300일 차 ---------------------------------
# 분산 투자 :  [6981.037233616553, 7729.180443401275, 6907.7338422383455]
# 투자 결과 :  21617.951519256174
#           영업일     인덱스  상승예측확률     실제수익률
# 0  281~300일 차     코스피  0.0003  0.096747
# 0  281~300일 차     코스닥  0.0183 -0.024930
# 0  281~300일 차     나스닥  0.9999 -0.022623
# 0  281~300일 차      항생  0.9933  0.082120
# 0  281~300일 차  S&P500  0.9997 -0.032886
# 301~320일 차 ---------------------------------
# 분산 투자 :  [7660.487099443903, 7758.603213766705, 7411.346633345559]
# 투자 결과 :  22830.43694655617
#           영업일     인덱스  상승예측확률     실제수익률
# 0  301~320일 차     코스피  0.0000  0.012993
# 0  301~320일 차     코스닥  0.0366  0.070734
# 0  301~320일 차     나스닥  0.9992  0.063073
# 0  301~320일 차      항생  0.9518  0.076689
# 0  301~320일 차  S&P500  1.0000  0.028499
# 321~340일 차 ---------------------------------
# 분산 투자 :  [22830.43694655617]
# 투자 결과 :  22830.43694655617
#           영업일     인덱스  상승예측확률     실제수익률
# 0  321~340일 차     코스피  0.1353  0.189463
# 0  321~340일 차     코스닥  0.0016  0.060264
# 0  321~340일 차     나스닥  0.0000  0.005752
# 0  321~340일 차      항생  0.0001  0.109381
# 0  321~340일 차  S&P500  0.0000  0.017772
# 341~360일 차 ---------------------------------
# 분산 투자 :  [22694.842737421804]
# 투자 결과 :  22694.842737421804
#           영업일     인덱스  상승예측확률     실제수익률
# 0  341~360일 차     코스피  0.0000  0.035962
# 0  341~360일 차     코스닥  0.0000  0.108726
# 0  341~360일 차     나스닥  0.6321 -0.005939
# 0  341~360일 차      항생  0.0000 -0.055141
# 0  341~360일 차  S&P500  0.0000 -0.009493
# 361~380일 차 ---------------------------------
# 분산 투자 :  [5774.857495628172, 5808.599206970996, 6992.65393196926, 5788.590883683853]
# 투자 결과 :  24364.70151825228
#           영업일     인덱스  상승예측확률     실제수익률
# 0  361~380일 차     코스피  0.0315  0.057766
# 0  361~380일 차     코스닥  0.6321  0.017827
# 0  361~380일 차     나스닥  1.0000  0.023774
# 0  361~380일 차      항생  1.0000  0.232466
# 0  361~380일 차  S&P500  1.0000  0.020248
# 381~400일 차 ---------------------------------
# 분산 투자 :  [12288.839203180498, 12117.577430283782]
# 투자 결과 :  24406.41663346428
#           영업일     인덱스  상승예측확률     실제수익률
# 0  381~400일 차     코스피  0.0000 -0.069087
# 0  381~400일 차     코스닥  0.0183 -0.100452
# 0  381~400일 차     나스닥  0.9991  0.008741
# 0  381~400일 차      항생  0.0000  0.049961
# 0  381~400일 차  S&P500  0.6321 -0.005317
# 401~420일 차 ---------------------------------
# 분산 투자 :  [8537.045188789652, 9204.521066370133, 8370.512851755206]
# 투자 결과 :  26112.079106914993
#           영업일     인덱스  상승예측확률     실제수익률
# 0  401~420일 차     코스피  1.0000  0.049361
# 0  401~420일 차     코스닥  1.0000  0.131406
# 0  401~420일 차     나스닥  1.0000  0.028891
# 0  401~420일 차      항생  0.2509 -0.027975
# 0  401~420일 차  S&P500  0.0183  0.045802
# 421~440일 차 ---------------------------------
# 분산 투자 :  [28489.818594649147]
# 투자 결과 :  28489.818594649147
#           영업일     인덱스  상승예측확률     실제수익률
# 0  421~440일 차     코스피  0.0025  0.076355
# 0  421~440일 차     코스닥  0.0000  0.081586
# 0  421~440일 차     나스닥  0.0180  0.026654
# 0  421~440일 차      항생  0.9820  0.091059
# 0  421~440일 차  S&P500  0.0000  0.016313
# 441~460일 차 ---------------------------------
# 분산 투자 :  [14693.430393311019, 16048.376725796323]
# 투자 결과 :  30741.80711910734
#           영업일     인덱스  상승예측확률     실제수익률
# 0  441~460일 차     코스피  0.0000  0.053460
# 0  441~460일 차     코스닥  0.0009  0.369992
# 0  441~460일 차     나스닥  0.9975  0.031486
# 0  441~460일 차      항생  0.9948  0.126604
# 0  441~460일 차  S&P500  0.0000  0.039824
# 461~480일 차 ---------------------------------
# 분산 투자 :  [29049.27155917178]
# 투자 결과 :  29049.27155917178
#           영업일     인덱스  상승예측확률     실제수익률
# 0  461~480일 차     코스피  0.9859 -0.055056
# 0  461~480일 차     코스닥  0.0000 -0.107243
# 0  461~480일 차     나스닥  0.0000  0.010765
# 0  461~480일 차      항생  0.0000 -0.008052
# 0  461~480일 차  S&P500  0.0002  0.017804
# 481~500일 차 ---------------------------------
# 분산 투자 :  [7753.223385097524, 10177.388622410199, 7800.027724473152, 7768.491069002042]
# 투자 결과 :  33499.130800982915
#           영업일     인덱스  상승예측확률     실제수익률
# 0  481~500일 차     코스피  1.0000  0.067596
# 0  481~500일 차     코스닥  0.7674  0.401397
# 0  481~500일 차     나스닥  0.9817  0.074041
# 0  481~500일 차      항생  0.1353  0.229018
# 0  481~500일 차  S&P500  0.6321  0.069699
# 501~520일 차 ---------------------------------
# 분산 투자 :  [33499.130800982915]
# 투자 결과 :  33499.130800982915
#           영업일     인덱스  상승예측확률     실제수익률
# 0  501~520일 차     코스피     0.0 -0.090939
# 0  501~520일 차     코스닥     0.0 -0.038876
# 0  501~520일 차     나스닥     0.0 -0.024093
# 0  501~520일 차      항생     0.0 -0.097937
# 0  501~520일 차  S&P500     0.0 -0.056554
# 521~540일 차 ---------------------------------
# 분산 투자 :  [12032.567503021008, 11200.312131757493, 10631.128941647634]
# 투자 결과 :  33864.00857642614
#           영업일     인덱스  상승예측확률     실제수익률
# 0  521~540일 차     코스피  1.0000  0.077571
# 0  521~540일 차     코스닥  1.0000  0.003039
# 0  521~540일 차     나스닥  0.0183 -0.041935
# 0  521~540일 차      항생  1.0000 -0.047934
# 0  521~540일 차  S&P500  0.0001 -0.040405
# 541~560일 차 ---------------------------------
# 분산 투자 :  [11403.490987330379, 10680.034566055472, 11455.041260916369]
# 투자 결과 :  33538.56681430222
#           영업일     인덱스  상승예측확률     실제수익률
# 0  541~560일 차     코스피  0.0000  0.065649
# 0  541~560일 차     코스닥  0.0000  0.126270
# 0  541~560일 차     나스닥  0.9997  0.010231
# 0  541~560일 차      항생  0.9503 -0.053860
# 0  541~560일 차  S&P500  0.9998  0.014798
# 561~580일 차 ---------------------------------
# 분산 투자 :  [17705.64557459351, 17380.74122006196]
# 투자 결과 :  35086.38679465547
#           영업일     인덱스  상승예측확률     실제수익률
# 0  561~580일 차     코스피  0.0067 -0.009643
# 0  561~580일 차     코스닥  0.0001 -0.033798
# 0  561~580일 차     나스닥  0.9942  0.055838
# 0  561~580일 차      항생  1.0000  0.036463
# 0  561~580일 차  S&P500  0.0001  0.032304
# 581~600일 차 ---------------------------------
# 분산 투자 :  [15426.714303314307, 15567.34091197875]
# 투자 결과 :  30994.055215293058
#           영업일     인덱스  상승예측확률     실제수익률
# 0  581~600일 차     코스피  1.0000 -0.120644
# 0  581~600일 차     코스닥  0.1353 -0.093427
# 0  581~600일 차     나스닥  0.0000  0.044885
# 0  581~600일 차      항생  0.9817 -0.112628
# 0  581~600일 차  S&P500  0.0000  0.018212
# 601~620일 차 ---------------------------------
# 분산 투자 :  [7165.983664440035, 7126.3784256783, 8157.6869698802775, 8109.915129463777]
# 투자 결과 :  30559.96418946239
#           영업일     인덱스  상승예측확률     실제수익률
# 0  601~620일 차     코스피  0.9975 -0.075180
# 0  601~620일 차     코스닥  0.9933 -0.080291
# 0  601~620일 차     나스닥  0.6321  0.052807
# 0  601~620일 차      항생  1.0000  0.046641
# 0  601~620일 차  S&P500  0.0000  0.048919
# 621~640일 차 ---------------------------------
# 분산 투자 :  [9724.4077796085, 9671.802866676684, 9492.77465515832]
# 투자 결과 :  28888.985301443507
#           영업일     인덱스  상승예측확률     실제수익률
# 0  621~640일 차     코스피  1.0000 -0.045378
# 0  621~640일 차     코스닥  0.6389 -0.050542
# 0  621~640일 차     나스닥  0.0003 -0.003199
# 0  621~640일 차      항생  1.0000 -0.068117
# 0  621~640일 차  S&P500  0.0000  0.018879
# 641~660일 차 ---------------------------------
# 분산 투자 :  [7795.00251116975, 8528.036801364415, 7335.261146842218, 6982.495476823505]
# 투자 결과 :  30640.795936199887
#           영업일     인덱스  상승예측확률     실제수익률
# 0  641~660일 차     코스피  0.9936  0.079304
# 0  641~660일 차     코스닥  0.9842  0.180801
# 0  641~660일 차     나스닥  0.9878  0.015648
# 0  641~660일 차      항생  1.0000 -0.033196
# 0  641~660일 차  S&P500  0.3670  0.020844
# 661~680일 차 ---------------------------------
# 분산 투자 :  [14578.12330338716, 13513.018386299376]
# 투자 결과 :  28091.141689686534
#           영업일     인덱스  상승예측확률     실제수익률
# 0  661~680일 차     코스피  0.3496 -0.155708
# 0  661~680일 차     코스닥  0.0000 -0.210812
# 0  661~680일 차     나스닥  0.9999 -0.048450
# 0  661~680일 차      항생  1.0000 -0.117972
# 0  661~680일 차  S&P500  0.0497 -0.048319
# ------------종료------------  ◆리밸런싱 수◆ :  34

# %%
KS2= KS11.rolling(150).mean().shift(-150)

# %%
plt.plot(KS11["Close"],label="Close")
plt.plot(KS2["Close"],'b.',label="Moving Average")
plt.ylabel('Close', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.legend()

# %%
import seaborn as sns
sns.lineplot(x=KS11["Close"],y=KS11.index)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-60-f9eac52890f0> in <module>
#       1 import seaborn as sns
# ----> 2 sns.lineplot(x=KS11["Close"],y=KS11.index)
#
# C:\Program Files\anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1082         ax = plt.gca()
#    1083
# -> 1084     p.plot(ax, kwargs)
#    1085
#    1086     return ax
#
# C:\Program Files\anaconda3\lib\site-packages\seaborn\relational.py in plot(self, ax, kws)
#     773                     err = "estimator must be None when specifying units"
#     774                     raise ValueError(err)
# --> 775                 x, y, y_ci = self.aggregate(y, x, units)
#     776             else:
#     777                 y_ci = None
#
# C:\Program Files\anaconda3\lib\site-packages\seaborn\relational.py in aggregate(self, vals, grouper, units)
#     703         # Group and get the aggregation estimate
#     704         grouped = vals.groupby(grouper, sort=self.sort)
# --> 705         est = grouped.agg(func)
#     706
#     707         # Exit early if we don't want a confidence interval
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     245
#     246         if isinstance(func, str):
# --> 247             return getattr(self, func)(*args, **kwargs)
#     248
#     249         elif isinstance(func, abc.Iterable):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1223         nv.validate_groupby_func("mean", args, kwargs, ["numeric_only"])
#    1224         return self._cython_agg_general(
# -> 1225             "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1226         )
#    1227
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     905
#     906         if len(output) == 0:
# --> 907             raise DataError("No numeric types to aggregate")
#     908
#     909         return self._wrap_aggregated_output(output)
#
# DataError: No numeric types to aggregate
