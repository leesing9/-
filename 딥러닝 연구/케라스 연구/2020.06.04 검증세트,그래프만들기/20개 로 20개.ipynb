# %% [markdown]
# # python 에 필요한 module 불러오기

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from math import exp

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import FinanceDataReader as fdr
from sklearn.metrics import accuracy_score
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 특성(MA,Stochastic,rsi) 추가

# %%
#특성 추가 ------------------------------------------
    #이동평균선
def get_MA(df):
    MA_26=df["Close"].rolling(26).mean()
    MA_52=df["Close"].rolling(52).mean()
    df=df.assign(MA_26=MA_26,MA_52=MA_52).dropna()
    
    return df

    
    #스토캐스틱
def get_stochastic(df, n=15, m=5, t=3):
    # n일중 최고가
    ndays_high = df.High.rolling(window=n, min_periods=1).max()
    # n일중 최저가
    ndays_low = df.Low.rolling(window=n, min_periods=1).min()
 
    # Fast%K 계산
    kdj_k = ((df.Close - ndays_low) / (ndays_high - ndays_low))*100
    # Fast%D (=Slow%K) 계산
    kdj_d = kdj_k.ewm(span=m).mean()
    # Slow%D 계산
    kdj_j = kdj_d.ewm(span=t).mean()
 
    # dataframe에 컬럼 추가
    df = df.assign(kdj_k=kdj_k, kdj_d=kdj_d, kdj_j=kdj_j).dropna()
    
    return df


def rsi(values):
    up = values[values>0].mean()
    down = -1*values[values<0].mean()
    return 100 * up / (up + down)
# Add Momentum_1D column for all 15 stocks.
# Momentum_1D = P(t) - P(t-1)

# %% [markdown]
# # 주식 데이터 불러오기

# %%
KS11 = fdr.DataReader("KS11","2007-01-01","2017-01-01") #코스피
KQ11= fdr.DataReader("KQ11","2007-01-01","2017-01-01") #코스닥
US500 = fdr.DataReader("US500","2007-01-01","2017-01-01") #SP500
HSI = fdr.DataReader("HSI","2007-01-01","2017-01-01") #항생지수
IXIC = fdr.DataReader("IXIC","2007-01-01","2017-01-01") #나스닥

KS11 = KS11.drop(['Volume'], axis = 1 )
KQ11 = KQ11.drop(['Volume'], axis = 1 )
US500 = US500.drop(['Volume'], axis = 1 )
HSI = HSI.drop(['Volume'], axis = 1 )
IXIC = IXIC.drop(['Volume'], axis = 1 )

# %% [markdown]
# # 사용될 변수 생성

# %%
예측dic={}
수익률dic={}
EndSwitch = 1 # 0이 되면 반복 종료
초기돈 = 10000
d,dd= 1, 20
BATCH = 20 # 리밸런싱 주기
count = 0 # 리밸런싱된 횟수 count
pred_dic={}
투자결과=[]

all_df=pd.DataFrame(columns=["영업일","인덱스","상승예측확률","실제수익률"]) # 총 table
set_df=pd.DataFrame(columns=["영업일","인덱스","상승예측확률","실제수익률"]) # 20일 주기 table

# %% [markdown]
# # Main 모델

# %%
for 인덱스,인덱스명 in zip([KS11,KQ11,IXIC,HSI,US500],["코스피","코스닥","나스닥","항생","S&P500"]):
    df = 인덱스
    
    # 특성 추가--------------------------------------------------------
    
    
        #스토캐스틱과 이동평균선
    df=get_stochastic(df)
    df=get_MA(df)
    
        #RSI
    df['Momentum_1D'] = (df['Close']-df['Close'].shift(1))
    df['RSI_14D'] = df['Momentum_1D'].rolling(center=False, window=14).apply(rsi)
    df=df.dropna()
    df=df[0:-(len(df)%BATCH)]
    df = df.drop(labels = ['Momentum_1D'], axis=1)
    
        #이동평균선
    MA_26=df["Close"].rolling(21).mean()
    df_MA=MA_26.dropna()
    df_char=df[20:] # df_char : 특성 모두 추가한 data, rolling,shifting 고려해서 제거
       #------------------------------------------------------------------
    
    
    
    
        # y ( target ) 생성 df_char= 값, df_MA= 이동평균선---------------------
    y=[]
    # 20개로 1개 예측
#     h=1
#     for x in range(1,len(df_char)+1-20):
#         if(df_char["Close"][x-1] > df_MA[20*h]):
#             y.append(0)
#         else:
#             y.append(1)
#         if(x%20==0):
#             h=h+1
#     #-------------------------------------------------------------------

#  # 20개로 20개 예측
    for x in range(0,len(df_char)):
        if(df_char["Close"][x]>df_MA[x]):
            y.append(0)
        else:
            y.append(1)
            
    df = df_char[:] # 20개 1개 예측이면 :-20, 20개로 20개예측이면 -20 제거
    nparr = df # 스케일링 할 데이터
    nparr2 = df # 스케일링 안한 데이터 백업
    
    #normalizing
    scaler = MinMaxScaler(feature_range=(0, 1))
    df["Close"]=scaler.fit_transform(nparr["Close"].values.reshape(-1,1))
    df["Open"]=scaler.fit_transform(nparr["Open"].values.reshape(-1,1))
    df["High"]=scaler.fit_transform(nparr["High"].values.reshape(-1,1))
    df["Low"]=scaler.fit_transform(nparr["Low"].values.reshape(-1,1))
    df["Change"]=scaler.fit_transform(nparr["Change"].values.reshape(-1,1))
    df["kdj_k"]=scaler.fit_transform(nparr["kdj_k"].values.reshape(-1,1))
    df["kdj_d"]=scaler.fit_transform(nparr["kdj_d"].values.reshape(-1,1))
    df["kdj_j"]=scaler.fit_transform(nparr["kdj_j"].values.reshape(-1,1))
    df["MA_26"]=scaler.fit_transform(nparr["MA_26"].values.reshape(-1,1))
    df["MA_52"]=scaler.fit_transform(nparr["MA_52"].values.reshape(-1,1))
    df["RSI_14D"]=scaler.fit_transform(nparr["RSI_14D"].values.reshape(-1,1))
    
    #-----
    #df["y"]=y
    #print(df.corr()) #상관관계 분석 ( 출력하고 싶다면 주석 제거)
    #df = df.drop(['y'],axis = 1)
    #-----
    
    df = df.drop(['Close','Open','High','Low','MA_26','MA_52'], axis = 1 ) # 상관관계 분석 후 관계 적은 특성(열) 제거
    X=df.values
    
    # train test val 세팅
    setlen=int(len(X)/20*0.7)*20 # 데이터를 7:3으로 나누고 20의 배수로 만듬
    X_train=X[:setlen]
    X_test=X[setlen:]
    y_train=y[:setlen]
    y_test=y[setlen:]
    
    setlen2=int(len(X_train)/20*0.3)*20 # 검증 데이터를 3:7으로 나누고 20의 배수로 만듬
    X_val = X_train[ : setlen2]
    y_val = y_train[ : setlen2]
    X_train2 = X_train[setlen2 : ]
    y_train2 = y_train[setlen2 : ]
    
    
    # 딥러닝 모델에 맞는 사이즈로 전처리
    X_train = np.reshape(X_train, (X_train.shape[0],1, X_train.shape[1]))
    X_test = np.reshape(X_test, (X_test.shape[0],1, X_test.shape[1]))
    
    X_val = np.reshape(X_val, (X_val.shape[0],1, X_val.shape[1]))
    X_train2 = np.reshape(X_train2, (X_train2.shape[0],1, X_train2.shape[1]))
    
    #LSTM모델 생성
    model = Sequential()
    model.add(LSTM(36, input_shape=(1, 5)))
    for i in range(2):
        model.add(Dense(18,activation='relu'))
        model.add(Dropout(0.2))
    model.add(Dense(1,activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    history = model.fit(X_train2, y_train2, epochs=6, batch_size=16,validation_data=(X_val,y_val),verbose=0)
    
    history_dict= history.history
    loss_values = history_dict['loss']
    val_loss_values = history_dict['val_loss']
    acc = history_dict['accuracy']
    epochs = range(1,len(acc)+1)

    plt.plot(epochs,loss_values,'bo',label='Training loss')
    plt.plot(epochs,val_loss_values,'b',label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    pred=np.where(model.predict(X_test)>0.5,1,0)
    예측dic[인덱스명]=pred # 예측 데이터 table에 추가
    수익률dic[인덱스명]=nparr2["Close"][setlen:] #투자 결과를 보기 위해 실제 수익률을 구함

    print(인덱스명, "정확도 : ", accuracy_score(y_test,np.where(model.predict(X_test)>0.5,1,0)))
       
    #모델 생성 완료 ------------------------------


End=1
while End==1: # 종료조건 ( END =0 )까지 반복
    
    # 날짜 출력 ------   
    day= str(d) +"~" + str(dd) + "일 차"
    print(day,"---------------------------------")
    # --------------- 
    set_df=pd.DataFrame(columns=["영업일","인덱스","상승예측확률","실제수익률"])

    
    
    for key,val in zip(예측dic.keys(),예측dic.values()): 
    
    
        # 비중조정없음--
        pred=val[BATCH-20:BATCH]
        pred_sum=sum(pred)
        #--------------------------------------------------
        
        
        # 예측 결과를 표(dataframe)로 보기 쉽게 정리-----------------
        if count==0:
            pred_dic[key]=pred_sum #pred_dic == {}
        else:
            pred_dic[key]=np.append(pred_dic[key],pred_sum)
        예측 = pred_sum/20
        실제수익률 = ((수익률dic[key][BATCH+19])/(수익률dic[key][BATCH]))-1
        turn_df=pd.DataFrame(data={"영업일":[day],"인덱스":[key],"상승예측확률":[예측],"실제수익률":[실제수익률] }, columns=["영업일","인덱스","상승예측확률","실제수익률"])
        set_df=pd.concat([set_df,turn_df])    
        #------------------------------------------------------------
        
    #--------데이터 20개 중 60% 이상 상승 예측 시 list에 추가
    earn_list=[]
    
    for x,y in zip(set_df["상승예측확률"],set_df["실제수익률"]):
        
        if x>=0.6:
            earn_list.append(y)
    
    #-------하나도 상승 예측이 아니었다면 규제 줄이기
    if len(earn_list)==0:
        for x,y in zip(set_df["상승예측확률"],set_df["실제수익률"]):
        
            if x>=0.4:
                earn_list.append(y)
    #---------------------------------------------------------------------
    
    
    earn_list2=[]
    if len(earn_list)!=0:
        초기돈=초기돈/(len(earn_list))
        for y in earn_list:
            earn_list2.append(초기돈+(초기돈*y))
        초기돈=sum(earn_list2)    
    else:
        earn_list2.append(초기돈)
    

    all_df=pd.concat([all_df,set_df])
    BATCH=BATCH+20

    print("분산 투자 : ",earn_list2)
    print("투자 결과 : ",초기돈)
    print(set_df.head(5))
    count=count+1
    d=d+20
    dd=dd+20

        #종료조건---------------

    if(len(수익률dic[key])==BATCH+20):
        End=0
        print("------------종료------------  ◆리밸런싱 수◆ : " , count)
        break
        #----------------------------------
# Out:
# 코스피 정확도 :  0.9180555555555555
# 코스닥 정확도 :  0.9305555555555556
# 나스닥 정확도 :  0.9175675675675675
# 항생 정확도 :  0.9138888888888889
# S&P500 정확도 :  0.9310810810810811
# 1~20일 차 ---------------------------------
# 분산 투자 :  [5326.83616402171, 4601.928999673223]
# 투자 결과 :  9928.765163694934
#        영업일     인덱스  상승예측확률     실제수익률
# 0  1~20일 차     코스피   [1.0]  0.065367
# 0  1~20일 차     코스닥  [0.35]  0.102187
# 0  1~20일 차     나스닥   [0.4]  0.126297
# 0  1~20일 차      항생   [0.6] -0.079614
# 0  1~20일 차  S&P500   [0.5]  0.094448
# 21~40일 차 ---------------------------------
# 분산 투자 :  [10285.842824308485]
# 투자 결과 :  10285.842824308485
#         영업일     인덱스  상승예측확률     실제수익률
# 0  21~40일 차     코스피   [0.3]  0.020861
# 0  21~40일 차     코스닥   [0.1]  0.046891
# 0  21~40일 차     나스닥  [0.15] -0.024537
# 0  21~40일 차      항생  [0.65]  0.035964
# 0  21~40일 차  S&P500  [0.15]  0.008930
# 41~60일 차 ---------------------------------
# 분산 투자 :  [9903.765560123047]
# 투자 결과 :  9903.765560123047
#         영업일     인덱스  상승예측확률     실제수익률
# 0  41~60일 차     코스피   [0.5] -0.030248
# 0  41~60일 차     코스닥  [0.15] -0.005948
# 0  41~60일 차     나스닥   [0.6] -0.037146
# 0  41~60일 차      항생   [0.2]  0.073023
# 0  41~60일 차  S&P500  [0.35]  0.013504
# 61~80일 차 ---------------------------------
# 분산 투자 :  [10315.558198025657]
# 투자 결과 :  10315.558198025657
#         영업일     인덱스  상승예측확률     실제수익률
# 0  61~80일 차     코스피   [0.2]  0.041697
# 0  61~80일 차     코스닥  [0.25] -0.065950
# 0  61~80일 차     나스닥  [0.65]  0.041579
# 0  61~80일 차      항생   [0.5] -0.017683
# 0  61~80일 차  S&P500   [0.4]  0.033366
# 81~100일 차 ---------------------------------
# 분산 투자 :  [11400.950417082608]
# 투자 결과 :  11400.950417082608
#          영업일     인덱스  상승예측확률     실제수익률
# 0  81~100일 차     코스피   [0.3]  0.006281
# 0  81~100일 차     코스닥   [1.0]  0.105219
# 0  81~100일 차     나스닥   [0.2]  0.054144
# 0  81~100일 차      항생   [0.2]  0.077464
# 0  81~100일 차  S&P500  [0.05]  0.028845
# 101~120일 차 ---------------------------------
# 분산 투자 :  [6081.350443045325, 5376.475760604604]
# 투자 결과 :  11457.826203649929
#           영업일     인덱스  상승예측확률     실제수익률
# 0  101~120일 차     코스피  [0.65]  0.066815
# 0  101~120일 차     코스닥   [0.8] -0.056837
# 0  101~120일 차     나스닥   [0.0]  0.011699
# 0  101~120일 차      항생  [0.05]  0.058945
# 0  101~120일 차  S&P500   [0.0] -0.002599
# 121~140일 차 ---------------------------------
# 분산 투자 :  [11457.826203649929]
# 투자 결과 :  11457.826203649929
#           영업일     인덱스  상승예측확률     실제수익률
# 0  121~140일 차     코스피   [0.1] -0.000317
# 0  121~140일 차     코스닥   [0.2]  0.104001
# 0  121~140일 차     나스닥  [0.05]  0.036121
# 0  121~140일 차      항생   [0.0] -0.057183
# 0  121~140일 차  S&P500  [0.05]  0.023154
# 141~160일 차 ---------------------------------
# 분산 투자 :  [2193.2935832419857, 2338.5567178995866, 2248.5723677247693, 2138.0386134378077, 2288.4142281519753]
# 투자 결과 :  11206.875510456124
#           영업일     인덱스  상승예측확률     실제수익률
# 0  141~160일 차     코스피   [0.4] -0.042884
# 0  141~160일 차     코스닥  [0.45]  0.020506
# 0  141~160일 차     나스닥  [0.45] -0.018761
# 0  141~160일 차      항생  [0.55] -0.066996
# 0  141~160일 차  S&P500   [0.5] -0.001375
# 161~180일 차 ---------------------------------
# 분산 투자 :  [5429.872176909512, 5660.06861129387]
# 투자 결과 :  11089.940788203381
#           영업일     인덱스  상승예측확률     실제수익률
# 0  161~180일 차     코스피   [0.9] -0.030975
# 0  161~180일 차     코스닥  [0.15] -0.029856
# 0  161~180일 차     나스닥   [0.2] -0.041301
# 0  161~180일 차      항생   [1.0]  0.010106
# 0  161~180일 차  S&P500  [0.25] -0.030152
# 181~200일 차 ---------------------------------
# 분산 투자 :  [2820.221419439814, 2653.854776028166, 3057.0063257240813, 2985.487183091132]
# 투자 결과 :  11516.569704283194
#           영업일     인덱스  상승예측확률     실제수익률
# 0  181~200일 차     코스피   [0.9]  0.017218
# 0  181~200일 차     코스닥  [0.65] -0.042788
# 0  181~200일 차     나스닥  [0.95]  0.102623
# 0  181~200일 차      항생   [0.1] -0.056873
# 0  181~200일 차  S&P500   [0.9]  0.076827
# 201~220일 차 ---------------------------------
# 분산 투자 :  [5557.275296029286, 6513.620526679044]
# 투자 결과 :  12070.895822708331
#           영업일     인덱스  상승예측확률     실제수익률
# 0  201~220일 차     코스피   [0.2] -0.031304
# 0  201~220일 차     코스닥  [0.75] -0.034908
# 0  201~220일 차     나스닥   [0.0] -0.009216
# 0  201~220일 차      항생  [0.75]  0.131174
# 0  201~220일 차  S&P500   [0.0]  0.006162
# 221~240일 차 ---------------------------------
# 분산 투자 :  [6185.188477868136, 7090.886092306002]
# 투자 결과 :  13276.074570174138
#           영업일     인덱스 상승예측확률     실제수익률
# 0  221~240일 차     코스피  [0.6]  0.024810
# 0  221~240일 차     코스닥  [0.6]  0.174873
# 0  221~240일 차     나스닥  [0.3] -0.032767
# 0  221~240일 차      항생  [0.3]  0.074202
# 0  221~240일 차  S&P500  [0.3] -0.034502
# 241~260일 차 ---------------------------------
# 분산 투자 :  [13590.444041239338]
# 투자 결과 :  13590.444041239338
#           영업일     인덱스  상승예측확률     실제수익률
# 0  241~260일 차     코스피  [0.75]  0.023679
# 0  241~260일 차     코스닥  [0.05]  0.090546
# 0  241~260일 차     나스닥  [0.35]  0.072181
# 0  241~260일 차      항생  [0.15] -0.060175
# 0  241~260일 차  S&P500   [0.4]  0.049838
# 261~280일 차 ---------------------------------
# 분산 투자 :  [17254.569729982846]
# 투자 결과 :  17254.569729982846
#           영업일     인덱스  상승예측확률     실제수익률
# 0  261~280일 차     코스피   [0.1]  0.021728
# 0  261~280일 차     코스닥   [0.0]  0.050774
# 0  261~280일 차     나스닥   [0.2]  0.008544
# 0  261~280일 차      항생   [0.5]  0.269610
# 0  261~280일 차  S&P500  [0.25]  0.001443
# 281~300일 차 ---------------------------------
# 분산 투자 :  [17446.566726001452]
# 투자 결과 :  17446.566726001452
#           영업일     인덱스  상승예측확률     실제수익률
# 0  281~300일 차     코스피  [0.15]  0.118905
# 0  281~300일 차     코스닥   [0.0]  0.114123
# 0  281~300일 차     나스닥   [0.3]  0.007590
# 0  281~300일 차      항생  [0.15]  0.030867
# 0  281~300일 차  S&P500   [0.4]  0.011127
# 301~320일 차 ---------------------------------
# 분산 투자 :  [5774.928756712058, 5422.592576448529, 5980.798750668594]
# 투자 결과 :  17178.32008382918
#           영업일     인덱스  상승예측확률     실제수익률
# 0  301~320일 차     코스피   [0.0] -0.041057
# 0  301~320일 차     코스닥   [0.0] -0.000456
# 0  301~320일 차     나스닥   [0.5] -0.006980
# 0  301~320일 차      항생  [0.45] -0.067566
# 0  301~320일 차  S&P500  [0.45]  0.028420
# 321~340일 차 ---------------------------------
# 분산 투자 :  [15324.8828285358]
# 투자 결과 :  15324.8828285358
#           영업일     인덱스  상승예측확률     실제수익률
# 0  321~340일 차     코스피  [0.55] -0.021636
# 0  321~340일 차     코스닥  [0.45]  0.083985
# 0  321~340일 차     나스닥  [0.45]  0.008384
# 0  321~340일 차      항생  [0.85] -0.107894
# 0  321~340일 차  S&P500   [0.2] -0.019790
# 341~360일 차 ---------------------------------
# 분산 투자 :  [7526.546731370546, 6987.155772450472]
# 투자 결과 :  14513.702503821018
#           영업일     인덱스  상승예측확률     실제수익률
# 0  341~360일 차     코스피  [0.85] -0.017735
# 0  341~360일 차     코스닥   [0.2]  0.046521
# 0  341~360일 차     나스닥   [0.1] -0.014118
# 0  341~360일 차      항생  [0.95] -0.088129
# 0  341~360일 차  S&P500   [0.4]  0.010775
# 361~380일 차 ---------------------------------
# 분산 투자 :  [14465.371455006269]
# 투자 결과 :  14465.371455006269
#           영업일     인덱스  상승예측확률     실제수익률
# 0  361~380일 차     코스피  [0.25] -0.133639
# 0  361~380일 차     코스닥  [0.15] -0.233191
# 0  361~380일 차     나스닥   [0.5] -0.007355
# 0  361~380일 차      항생  [0.55] -0.188903
# 0  361~380일 차  S&P500  [0.65] -0.003330
# 381~400일 차 ---------------------------------
# 분산 투자 :  [5338.374149603196, 5401.6811025609695, 5385.665054392095]
# 투자 결과 :  16125.72030655626
#           영업일     인덱스  상승예측확률     실제수익률
# 0  381~400일 차     코스피   [0.9]  0.107135
# 0  381~400일 차     코스닥   [0.8]  0.120265
# 0  381~400일 차     나스닥  [0.25] -0.109017
# 0  381~400일 차      항생   [1.0]  0.116943
# 0  381~400일 차  S&P500   [0.2] -0.081461
# 401~420일 차 ---------------------------------
# 분산 투자 :  [5388.145991146122, 5328.713113445004, 5536.13499441921]
# 투자 결과 :  16252.994099010335
#           영업일     인덱스  상승예측확률     실제수익률
# 0  401~420일 차     코스피   [0.5]  0.041061
# 0  401~420일 차     코스닥   [0.7]  0.002401
# 0  401~420일 차     나스닥  [0.75] -0.008656
# 0  401~420일 차      항생   [0.4] -0.017157
# 0  401~420일 차  S&P500   [0.8]  0.029933
# 421~440일 차 ---------------------------------
# 분산 투자 :  [17656.91375907493]
# 투자 결과 :  17656.91375907493
#           영업일     인덱스  상승예측확률     실제수익률
# 0  421~440일 차     코스피   [0.0] -0.071905
# 0  421~440일 차     코스닥  [0.35] -0.033693
# 0  421~440일 차     나스닥  [0.45]  0.108856
# 0  421~440일 차      항생   [0.3] -0.039434
# 0  421~440일 차  S&P500   [0.6]  0.086379
# 441~460일 차 ---------------------------------
# 분산 투자 :  [15250.23303381752]
# 투자 결과 :  15250.23303381752
#           영업일     인덱스  상승예측확률     실제수익률
# 0  441~460일 차     코스피  [0.45] -0.029205
# 0  441~460일 차     코스닥  [0.55] -0.075437
# 0  441~460일 차     나스닥  [0.05]  0.002884
# 0  441~460일 차      항생   [1.0] -0.136302
# 0  441~460일 차  S&P500   [0.0] -0.015991
# 461~480일 차 ---------------------------------
# 분산 투자 :  [6955.343268690888, 6598.5474341904555]
# 투자 결과 :  13553.890702881345
#           영업일     인덱스 상승예측확률     실제수익률
# 0  461~480일 차     코스피  [0.7] -0.087838
# 0  461~480일 차     코스닥  [0.4]  0.080709
# 0  461~480일 차     나스닥  [0.2] -0.014884
# 0  461~480일 차      항생  [0.7] -0.134630
# 0  461~480일 차  S&P500  [0.2] -0.004137
# 481~500일 차 ---------------------------------
# 분산 투자 :  [6816.53823212537, 7369.584914500382]
# 투자 결과 :  14186.123146625752
#           영업일     인덱스  상승예측확률     실제수익률
# 0  481~500일 차     코스피  [0.75]  0.005842
# 0  481~500일 차     코스닥   [0.4] -0.142363
# 0  481~500일 차     나스닥  [0.45] -0.105238
# 0  481~500일 차      항생  [0.95]  0.087449
# 0  481~500일 차  S&P500   [0.5] -0.054845
# 501~520일 차 ---------------------------------
# 분산 투자 :  [5393.815422536548, 4640.643958734499, 5019.10010456321]
# 투자 결과 :  15053.55948583426
#           영업일     인덱스  상승예측확률     실제수익률
# 0  501~520일 차     코스피   [0.5]  0.081590
# 0  501~520일 차     코스닥   [0.6]  0.140653
# 0  501~520일 차     나스닥   [0.9] -0.018623
# 0  501~520일 차      항생  [0.25]  0.041662
# 0  501~520일 차  S&P500   [0.9]  0.061411
# 521~540일 차 ---------------------------------
# 분산 투자 :  [15744.5087838283]
# 투자 결과 :  15744.5087838283
#           영업일     인덱스 상승예측확률     실제수익률
# 0  521~540일 차     코스피  [0.0]  0.021445
# 0  521~540일 차     코스닥  [0.3]  0.001383
# 0  521~540일 차     나스닥  [0.4]  0.045899
# 0  521~540일 차      항생  [0.2] -0.030133
# 0  521~540일 차  S&P500  [0.3]  0.059164
# 541~560일 차 ---------------------------------
# 분산 투자 :  [15140.82340942898]
# 투자 결과 :  15140.82340942898
#           영업일     인덱스  상승예측확률     실제수익률
# 0  541~560일 차     코스피   [0.4] -0.038343
# 0  541~560일 차     코스닥  [0.15]  0.001405
# 0  541~560일 차     나스닥   [0.0]  0.005274
# 0  541~560일 차      항생  [0.35]  0.085353
# 0  541~560일 차  S&P500   [0.0]  0.025600
# 561~580일 차 ---------------------------------
# 분산 투자 :  [7660.395772797405, 6958.936739678034]
# 투자 결과 :  14619.33251247544
#           영업일     인덱스  상승예측확률     실제수익률
# 0  561~580일 차     코스피   [0.5]  0.011886
# 0  561~580일 차     코스닥   [0.3]  0.025528
# 0  561~580일 차     나스닥   [0.0] -0.000579
# 0  561~580일 차      항생  [0.55] -0.080772
# 0  561~580일 차  S&P500  [0.05]  0.010527
# 581~600일 차 ---------------------------------
# 분산 투자 :  [7185.555631929808, 7429.738449669839]
# 투자 결과 :  14615.294081599648
#           영업일     인덱스  상승예측확률     실제수익률
# 0  581~600일 차     코스피  [0.55]  0.052860
# 0  581~600일 차     코스닥  [0.55]  0.053453
# 0  581~600일 차     나스닥   [0.9] -0.016979
# 0  581~600일 차      항생  [0.45]  0.116118
# 0  581~600일 차  S&P500   [0.8]  0.016426
# 601~620일 차 ---------------------------------
# 분산 투자 :  [7552.619377161287, 7375.740461150598]
# 투자 결과 :  14928.359838311884
#           영업일     인덱스  상승예측확률     실제수익률
# 0  601~620일 차     코스피  [0.55]  0.033523
# 0  601~620일 차     코스닥  [0.55]  0.009318
# 0  601~620일 차     나스닥  [0.35]  0.044999
# 0  601~620일 차      항생   [0.0]  0.091305
# 0  601~620일 차  S&P500  [0.35]  0.101126
# 621~640일 차 ---------------------------------
# 분산 투자 :  [14928.359838311884]
# 투자 결과 :  14928.359838311884
#           영업일     인덱스 상승예측확률     실제수익률
# 0  621~640일 차     코스피  [0.1]  0.013450
# 0  621~640일 차     코스닥  [0.3] -0.081264
# 0  621~640일 차     나스닥  [0.2]  0.036536
# 0  621~640일 차      항생  [0.0]  0.002486
# 0  621~640일 차  S&P500  [0.2]  0.010315
# 641~660일 차 ---------------------------------
# 분산 투자 :  [7555.864744314471, 7204.4424522291]
# 투자 결과 :  14760.30719654357
#           영업일     인덱스  상승예측확률     실제수익률
# 0  641~660일 차     코스피  [0.25] -0.003767
# 0  641~660일 차     코스닥  [0.95]  0.012283
# 0  641~660일 차     나스닥   [0.0]  0.001559
# 0  641~660일 차      항생   [0.6] -0.034798
# 0  641~660일 차  S&P500   [0.0] -0.028896
# 661~680일 차 ---------------------------------
# 분산 투자 :  [7334.2069852519035, 7313.273588489941]
# 투자 결과 :  14647.480573741845
#           영업일     인덱스  상승예측확률     실제수익률
# 0  661~680일 차     코스피   [0.4] -0.052996
# 0  661~680일 차     코스닥  [0.35] -0.157626
# 0  661~680일 차     나스닥   [0.4] -0.005262
# 0  661~680일 차      항생  [0.85] -0.006226
# 0  661~680일 차  S&P500   [0.6] -0.009062
# 681~700일 차 ---------------------------------
# 분산 투자 :  [4833.340443179798, 4279.531737253249, 4468.279453156493]
# 투자 결과 :  13581.15163358954
#           영업일     인덱스  상승예측확률     실제수익률
# 0  681~700일 차     코스피   [1.0] -0.010067
# 0  681~700일 차     코스닥   [1.0] -0.123495
# 0  681~700일 차     나스닥   [0.2]  0.009486
# 0  681~700일 차      항생  [0.75] -0.084837
# 0  681~700일 차  S&P500  [0.45]  0.016814
# ------------종료------------  ◆리밸런싱 수◆ :  35

# %%
y
# Out:
# 0.11982975662390616

# %%
turn_df
# Out:
#           영업일     인덱스  상승예측확률     실제수익률
# 0  681~700일 차  S&P500     0.0 -0.045091
